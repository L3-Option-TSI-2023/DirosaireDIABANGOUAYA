# %% [markdown]
# # [C++] 02 - Fonctions et fichiers - Exercice 3
# Reprendre l'exercice [C++] 02 - 2 en plaçant les déclarations anticipées dans un fichier d'en-tête es.h

# %%
# %%writefile es.h
#
# float writte(std::string directive="");
# float print(int a, float b);
# Out:
# Writing es.h

# %% [markdown]
# #Correction 18 / 20
#
# Ok, juste deux remarques :
#
#
# *   il faudrait une fonction de saisie différente par type
# *   la fonction d'affichage print ne devrait pas retourner de valeur (void)

# %%
# %%writefile main.cpp
#
# #include <iostream>
#
#
# // Saisie des nombres sans precision de type
# float writte(std::string directive="")
# {
#   float unkown_type_nber;
#
#   std::cout << directive << "\n";
#   std::cin >> unkown_type_nber;
#   return unkown_type_nber;
# }
#
#
# // Affichage de la somme
# float print(int a, float b)
# {
#   float sum{ static_cast<float>(a+b) };
#
#   std::cout << "\nVous avez entré les valeurs suivantes : "
#             << a << " et " << b
#             << "\nLeur somme fait : " << sum;
#
#   return 0;
# }
#
#
# int main(void)
# {
#   int nber_1{
#     static_cast<int>(writte("Saisissez un chiffre/nombre entier :"))
#   };
#
#   float nber_2{
#     static_cast<float>(writte("Saisissez un chiffre/nombre decimal :"))
#   };
#
#   print(nber_1, nber_2);
#
#   return 0;
# }
# Out:
# Writing main.cpp

# %%
# %%shell
# g++ main.cpp -o output
# ./output
# Out:
# Saisissez un chiffre/nombre entier :
# 1
# Saisissez un chiffre/nombre decimal :
# 1.56
#
# Vous avez entré les valeurs suivantes : 1 et 1.56
# Leur somme fait : 2.56
