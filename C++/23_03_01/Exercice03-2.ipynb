# %% [markdown]
# # [C++] 03 - Types de base - Exercice 2
# Ecrire un programme qui calcule la hauteur de chute d'un objet.
#
# Pour commencer, le programme doit demander à l'utilisateur la hauteur initiale de l'objet. On suppose que l'objet est soumis à un champ de pesanteur normal ($g=9.8m.s^{-2}$) et qu'il possède une vitesse nulle à $t=0$.
#
# On écrira une fonction qui calcule la hauteur de l'objet à un temps donné $t$.
#
# La distance de chute est donnée par : $d=\frac{gt^2}{2}$.
#
# Dans la fonction main, appeler la fonction pour différents temps.

# %%
# %%writefile main.cpp
#
# #include <iostream>
#
# float instant_height(float d, float t)
# {
#
#   // ih: initial height
#   // d: distance
#   // t: time
#
#   float ih;
#   constexpr float g = { 9.8 };
#
#   // d = initial height - final height = (g*t*t)/2
#   // => final height = (g*t*t)/2 - initial height
#
#   d = (g*t*t)/2 - ih;
#
#   return abs(d);
# }
#
# int main(void)
# {
#   float falling_height = {0},
#   initial_height= {0},
#   time;
#
#   std::cout<< "\nEntrer la hauteur initiale (m): \n";
#   std::cin >> initial_height;
#
#   std::cout<<"Hauteur initiale entree => " << initial_height ;
#   std::cout<<"\nA t=3s => " << instant_height(initial_height, 3) << "m\n";
#   std::cout<<"A t=6s => " << instant_height(initial_height, 6) << "m\n";
#   std::cout<<"A t=10s => " << instant_height(initial_height, 10) << "m\n";
#
#   return 0;
# }
# Out:
# Overwriting main.cpp

# %%
# %%shell
# g++ main.cpp -o output
# ./output
# Out:
# Entrer la hauteur initiale (m):
# 10
# Hauteur initiale entree => 10
# A t=3s => 44m
# A t=6s => 3062m
# A t=10s => 490m
